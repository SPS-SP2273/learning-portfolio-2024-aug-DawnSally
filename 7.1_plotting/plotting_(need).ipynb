# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %%
from matplotlib import pyplot as plt 
import numpy as np

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
# Lengend shows what the graph is 
plt.legend(loc='upper left')
plt.savefig('hahaha.png', dpi=150)
plt.show()

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
# To save figure as a png file and you can change the quality of the figure through dpi- resolution) 
plt.savefig('plot.png', dpi=150)
plt.show()

# %% [markdown]
# # Difference between png and jpg
# png can have transparent background, jpg cannot
#
# jpg files are smaller, the more you save it, the more information you lose. jpg use algorithm to compress your files
#
# jpg gets pixelated when you zoom in, it does not have the information to make it nice and smooth
#
# pdf does not change; vector format- remembers the formula to draw the line, but does not remember the points

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='yellow', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
# Alpha gives the opacity of the grid 
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='yellow', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
# Alpha gives the opacity of the grid 
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

for alpha in [.25,.75,1]:
# Lets start plotting
    plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
    plt.plot(x, y_2, label='Y2 values', color='blue', )
    plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
                 label='Y3 with errors', color='green')
    plt.xlabel('x-values')
    plt.ylabel('y-values')
    plt.title('X vs Y')
    plt.grid(alpha=.25)
    plt.legend(loc='upper left')
    plt.savefig(f'hahaha_{alpha=}.png', dpi=300)
    plt.clf()

# %% [markdown]
# # 2 Better with NumPy

# %%
xx = np.linspace(1,6)
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

plt.plot(xx, np.sin(xx**2), 'k--')
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
                label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
file_url = 'https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Complete_TAVG_daily.txt'
data=np.loadtxt(file_url, skiprows=23)
plt.plot(data[:,1],data[:,-1], alpha =.5)

# %%
years = data[:,1]
anomaly=data[:,-1]
plt.plot(year,anomaly, alpha=.5)

year_min, year_max = years.min(), years.max()
plt.hlines(0,year_min,year_max,color='r--')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 6
#       3 plt.plot(year,anomaly, alpha=.5)
#       5 year_min, year_max = years.min(), years.max()
# ----> 6 plt.hlines(0,year_min,year_max,color='r--')
#
# File C:\ProgramData\miniconda3\Lib\site-packages\matplotlib\pyplot.py:3528, in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    3516 @_copy_docstring_and_deprecators(Axes.hlines)
#    3517 def hlines(
#    3518     y: float | ArrayLike,
#    (...)
#    3526     **kwargs,
#    3527 ) -> LineCollection:
# -> 3528     return gca().hlines(
#    3529         y,
#    3530         xmin,
#    3531         xmax,
#    3532         colors=colors,
#    3533         linestyles=linestyles,
#    3534         label=label,
#    3535         **({"data": data} if data is not None else {}),
#    3536         **kwargs,
#    3537     )
#
# ...

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
