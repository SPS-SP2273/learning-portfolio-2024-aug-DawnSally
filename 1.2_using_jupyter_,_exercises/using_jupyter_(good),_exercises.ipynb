# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %% [markdown]
# ## Footnotes

# %% [markdown]
# # Exercise 1 (Learning to interrupt)

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...

# %% [markdown]
# # Exercise 2 (Resetting & Restarting the Kernel)

# %%
print = 'PRINT'

# %%
print('Hello World')

# %% [markdown]
# # Exercise 3 (Timing Stuff)

# %%
print(squares = [i**2 for i in range(10)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(squares = [i**2 for i in range(10)])
#
# TypeError: 'squares' is an invalid keyword argument for print()

# %%
print(squares = list()
for i in range(10):
    squares.append(i**2))
# Out:
#   Cell In[10], line 1
#     print(squares = list()
#           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
print(\sqrt[i**2 for i in range(10)])
# Out:
#   Cell In[16], line 1
#     print(\sqrt[i**2 for i in range(10)])
#            ^
# SyntaxError: unexpected character after line continuation character

# %%
print( list()for i in range(10))
# Out:
# <generator object <genexpr> at 0x000002736E1D2C20>

# %%
# %timeit x=0
# Out:
# 48.4 ns ± 0.675 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
print(i in range(10), squares.append(i**2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(i in range(10), squares.append(i**2))
#
# NameError: name 'i' is not defined
