# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# # Task 1

# %%
dictionary = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

# %%
result = 'oct-08_singapore.txt'
for month, number in dictionary.items():
    result = result.replace(month, number)
    result = result.replace('_','-')
    
result
# Out:
# '10-08-singapore.txt'

# %% [markdown]
# # Task 2

# %%
def rename_my_file(old_file_name):
    for month, number in dictionary.items():
        old_file_name = old_file_name.replace(month, number)
        old_file_name = old_file_name.replace('_','-')
    return old_file_name

# %%
rename_my_file('nov-08_singapore.txt')
# Out:
# '11-08-singapore.txt'

# %% [markdown]
# # Task 3

# %%
old_file_name = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
for date in old_file_name:
    new_date = rename_my_file(date)
    print(f"{date} ----> {new_date}")
# Out:
# oct-08_singapore.txt ----> 10-08-singapore.txt
# jul-10_cairo.txt ----> 07-10-cairo.txt
# may-15_dhaka.txt ----> 05-15-dhaka.txt
# may-13_cairo.txt ----> 05-13-cairo.txt
# oct-21_cairo.txt ----> 10-21-cairo.txt
# jan-10_singapore.txt ----> 01-10-singapore.txt
# jun-20_tokyo.txt ----> 06-20-tokyo.txt
# aug-06_jakarta.txt ----> 08-06-jakarta.txt
# dec-21_karachi.txt ----> 12-21-karachi.txt
# jan-01_tokyo.txt ----> 01-01-tokyo.txt

# %% [markdown]
# # Task 4

# %%
import glob, os

# %%
folder = 'os-collaboration-exercise-data'
search_path = os.path.join(folder,'*.txt')
all_files = glob.glob(search_path, recursive = True)

# %%
# Must split because our function cannot change name when there is the os-collaboration-exercise-data infront of it
txt_files = [file.split(os.path.sep)[-1] for file in all_files]

# %%
for name in txt_files:
    new_name = rename_my_file(name)

    old_path=os.path.join(folder,name)
    new_path=os.path.join(folder,new_name)
    os.rename(old_path,new_path)

# %% [markdown]
# # Task 5

# %%
cities = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
for city in cities:
    os.mkdir(city)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[13], line 2
#       1 for city in cities:
# ----> 2     os.mkdir(city)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Cairo'

# %% [markdown]
# # Task 6

# %%
import shutil

# %%
folder = 'os-collaboration-exercise-data'
search_path = os.path.join(folder,'*Cairo*')
files = glob.glob(search_path, recursive=True)

# %%
files
# Out:
# ['os-collaboration-exercise-data\\01-02-cairo.txt',
#  'os-collaboration-exercise-data\\01-03-cairo.txt',
#  'os-collaboration-exercise-data\\01-04-cairo.txt',
#  'os-collaboration-exercise-data\\01-05-cairo.txt',
#  'os-collaboration-exercise-data\\01-07-cairo.txt',
#  'os-collaboration-exercise-data\\01-08-cairo.txt',
#  'os-collaboration-exercise-data\\01-09-cairo.txt',
#  'os-collaboration-exercise-data\\01-11-cairo.txt',
#  'os-collaboration-exercise-data\\01-12-cairo.txt',
#  'os-collaboration-exercise-data\\01-13-cairo.txt',
#  'os-collaboration-exercise-data\\01-15-cairo.txt',
#  'os-collaboration-exercise-data\\01-16-cairo.txt',
#  'os-collaboration-exercise-data\\01-19-cairo.txt',
#  'os-collaboration-exercise-data\\01-20-cairo.txt',
#  'os-collaboration-exercise-data\\01-21-cairo.txt',
#  'os-collaboration-exercise-data\\01-23-cairo.txt',
#  'os-collaboration-exercise-data\\01-27-cairo.txt',
#  'os-collaboration-exercise-data\\01-30-cairo.txt',
# ...

# %%
path = '.\\Cairo\\'
for txt in files:
    shutil.copy(txt,path)

# %% [markdown]
# # Task 7

# %%
folder = 'os-collaboration-exercise-data'
search_path = os.path.join(folder,'*Dhaka*')
dhaka = glob.glob(search_path, recursive=True)

# %% [markdown]
# #own comment : glob.glob(search_path) is to search for files with "dhaka" and put it as output

# %%
dhaka
# Out:
# ['os-collaboration-exercise-data\\01-15-dhaka.txt',
#  'os-collaboration-exercise-data\\02-01-dhaka.txt',
#  'os-collaboration-exercise-data\\02-04-dhaka.txt',
#  'os-collaboration-exercise-data\\02-08-dhaka.txt',
#  'os-collaboration-exercise-data\\02-12-dhaka.txt',
#  'os-collaboration-exercise-data\\02-14-dhaka.txt',
#  'os-collaboration-exercise-data\\02-20-dhaka.txt',
#  'os-collaboration-exercise-data\\02-22-dhaka.txt',
#  'os-collaboration-exercise-data\\03-16-dhaka.txt',
#  'os-collaboration-exercise-data\\04-19-dhaka.txt',
#  'os-collaboration-exercise-data\\04-20-dhaka.txt',
#  'os-collaboration-exercise-data\\04-23-dhaka.txt',
#  'os-collaboration-exercise-data\\05-01-dhaka.txt',
#  'os-collaboration-exercise-data\\05-02-dhaka.txt',
#  'os-collaboration-exercise-data\\05-04-dhaka.txt',
#  'os-collaboration-exercise-data\\05-05-dhaka.txt',
#  'os-collaboration-exercise-data\\05-10-dhaka.txt',
#  'os-collaboration-exercise-data\\05-11-dhaka.txt',
# ...

# %%
path = '.\\Dhaka\\'
for x in dhaka:
    shutil.copy(x,path)

# %%
remaining_cities = [ 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
folder = 'os-collaboration-exercise-data'
for y in remaining_cities:
    search_path = os.path.join(folder,f'*{y}*')
    remainder = glob.glob(search_path, recursive=True)
    path = y
    for remain in remainder:
        shutil.copy(remain,path)

# %% [markdown]
# #For my own understanding :
# dont need to put quotation for path because y is each city in the remaining_cities list
